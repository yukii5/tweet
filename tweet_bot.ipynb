# %% [markdown]
# <a href="https://colab.research.google.com/github/yukii5/tweet/blob/main/tweet_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CONSUMER_KEY = 'eq8El01wwzG2aADFfSVOiLMj0'
CONSUMER_SECRET = 'w8XcGZBcFd9DtSbseXmiUsmP4hJdUOYr9E1AEKxiCOS2NCOpt8'
ACCESS_TOKEN = '3047313139-1bgSP38qswQ4iDiFtFWGUc2kbktuRmEqeQ3IzKO'
ACCESS_TOKEN_SECRET = 'JHj8VsML2tZ5KNURKovSAdavluULPNFkcQG1Q3vLA3U0o'

# %%
from requests_oauthlib import OAuth1Session
from time import sleep
import json
#４つのキーをセット
CK = CONSUMER_KEY
CS = CONSUMER_SECRET
AT = ACCESS_TOKEN
ATS = ACCESS_TOKEN_SECRET
 
# 対象ツイートを検索
def search_tweet(search_word):
    url = "https://api.twitter.com/1.1/search/tweets.json"
    twitter = OAuth1Session(CK, CS, AT, ATS)
    req = twitter.get(url, params = search_word)
 
    if req.status_code == 200:
        tweet = json.loads(req.text)
        search_timeline = json.loads(req.text)
        for tweet in search_timeline['statuses']:
            print(tweet['user']['screen_name'] + "(" + tweet['user']['name'] + ") > " + tweet['text'])
            print("(tweet id = " + tweet['id_str'] + ")")
            print("-"*10)
            return tweet['id'] 
    else:
        print("ERROR: %d" % req.status_code)

# %%
# いいね        
def favorite_tweet(tweet_id):
    url = "https://api.twitter.com/1.1/favorites/create.json"
    params = {'id' : tweet_id,
             #'include_entities' : 'True'
             }
    twitter = OAuth1Session(CK, CS, AT, ATS)
    req = twitter.post(url, params = params)
    
    if req.status_code == 200:
        print('↑のツイートを いいね しました')
        print("-・"*30)
    else:
        print("ERROR: %d" % req.status_code)
        print("-・"*30)

# %%
if __name__ == '__main__':
    count = 10
    tweet_id = 9999999999999999999
    for i in range(count):
        #print(tweet_id)
        search_word = {'q' : "#駆け出しエンジニアと繋がりたい",  #検索文字列
                       'count':1,
                       'lang' : 'ja', 
                       'result_type' : 'recent',
                       'max_id' : str(tweet_id-1)
                       }
        tweet_id = search_tweet(search_word)
        favorite_tweet(tweet_id)
        if not i==count-1: sleep(60)
 
print("finish")
# Out:
# nobu_easylife(のぶ / トロッコ人生) > 朝活やってるみんなおはよう☀️
#
# 自堕落意識低い系の僕だけど、朝起きるのは少し早めなんだよね
# ちなみに朝起きて太陽の光を浴びながら散歩するのは本当にオススメだよ
# 勉強頑張ってるみんな、休憩時間作って15分くらい散歩すると人生変わる… https://t.co/VUK08kcH32
# (tweet id = 1387879486293610499)
# ----------
# ↑のツイートを いいね しました
# -・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・
# setsu_mini01(せつ｜エンジニア1年生|ZONE1期生) > おはせつ☀️
#
# 今日でつよつよエンジニアと働くの最後🥺
# これからレビューしてもらえないと思うと、、、
#
# 成長した姿を見せるために絶対に今日中にプルリクしてレビューしてもらう！
#
# 金曜日ですが気持ちは月曜日🔥
#
# #駆け出しエンジニアと繋がりたい
# #プログラミング初心者
# #朝活
# (tweet id = 1387879362683363331)
# ----------
# ↑のツイートを いいね しました
# -・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・
# seichiwebfire(せーいち⭐️健康すぎるウェブ制作フリーランス) > おはようございます！
#
# #今日の積み上げ
# ✅営業20件
# ✅仮想通貨セミナー
# ✅codethrough合同MTG
#
# キンコン西野さんの初心者向けの仮想通貨セミナーを受けてきます
# 仮想通貨を基礎から学ぶことで、今後の資産運用につなげて… https://t.co/hvZOCagxly
# (tweet id = 1387879292760035331)
# ----------
# ↑のツイートを いいね しました
# -・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・-・
# ...
